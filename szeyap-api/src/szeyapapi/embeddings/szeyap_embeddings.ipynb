# %%
import torch
def check_mps():
    if torch.backends.mps.is_available():
        print("MPS is available")
    else:
        print("MPS is not available")
        return False

    if torch.backends.mps.is_built():
        print("MPS is built")
    else:
        print("MPS is not built")
        return False
    return True

check_mps()
# Out:
# MPS is available
# MPS is built
# True

# %%
target_dictionary = "gene_chin" # or "stephen_li"
model_name = "all-MiniLM-L6-v2"

# Load model and move to GPU
if torch.cuda.is_available():
    device = "cuda"
elif check_mps():
    device = "mps"
else:
    print("No GPU available, using CPU")
    device = "cpu"
# Out:
# MPS is available
# MPS is built

# %%
import json
from langchain_huggingface import HuggingFaceEmbeddings
from sentence_transformers import SentenceTransformer
from langchain.vectorstores import FAISS
from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from tqdm import tqdm  # Import tqdm for progress bar

# Load JSON list
with open(f"../data/{target_dictionary}_dictionary.json", "r", encoding="utf-8") as f:
    data = json.load(f)  # list of dictionaries

# Create documents
docs = []
for entry in data:
    trad = entry.get("TRAD", "")
    simp = entry.get("SIMP", "")
    jyutping = entry.get("JYUTPING", "")
    penyim = entry.get("PENYIM", "")
    defn = entry.get("DEFN", "")

    content = f"Traditional: {trad}\nSimplified: {simp}\nJyutping: {jyutping}\nTaishanese (Penyim): {penyim}\nDefinition: {defn}"
    docs.append(Document(page_content=content, metadata=entry))

# Optionally split long docs
splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=0)
split_docs = splitter.split_documents(docs)

# Your documents
documents = split_docs  # Assume this is already created

# Initialize HuggingFaceEmbeddings with the model name
embedding_model = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs={'device': device} # Pass device as a model_kwarg
)

# Prepare text
texts = [doc.page_content for doc in documents]
metadatas = [doc.metadata for doc in documents]

# Embed in batches (HuggingFaceEmbeddings handles batching internally)
all_embeddings = []

for i in tqdm(range(0, len(texts), 100), desc="Embedding"): # Use a reasonable batch size
    batch = texts[i:i + 100]
    embeddings = embedding_model.embed_documents(batch)
    all_embeddings.extend(embeddings)
# Out:
# Embedding: 100%|██████████| 819/819 [04:31<00:00,  3.01it/s]

# %%
# Rebuild docs (FAISS needs LangChain Documents)
reconstructed_docs = [Document(page_content=texts[i], metadata=metadatas[i]) for i in range(len(texts))]

# Reconstruct (text, embedding) tuples
text_embedding_pairs = list(zip(texts, all_embeddings))

# Create FAISS vector store
vectorstore = FAISS.from_embeddings(text_embedding_pairs, embedding_model)

# Save locally
vectorstore.save_local(f"{target_dictionary}_{model_name}_embeddings")

# %%
vectorstore = FAISS.load_local(f"{target_dictionary}_{model_name}_embeddings", embedding_model, allow_dangerous_deserialization=True)
# retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k":5})

# %%
docs_and_scores = vectorstore.similarity_search_with_score("I am very happy", k=50)
docs_and_scores = sorted(docs_and_scores, key=lambda x: x[1], reverse=True)

print("🔍 Similarity Search Results for 'happy'")
print("=" * 50)

for i, (doc, score) in enumerate(docs_and_scores, 1):
    print(f"\n📍 Result #{i}")
    print(f"   Similarity Score: {score:.4f}")
    print(f"   {'─' * 40}")
    
    # Parse the content to extract structured information
    lines = doc.page_content.strip().split('\n')
    for line in lines:
        if ':' in line:
            key, value = line.split(':', 1)
            key = key.strip()
            value = value.strip()
            
            # Add emoji indicators for different fields
            if key == "Traditional":
                print(f"   🈶 {key}: {value}")
            elif key == "Simplified":
                print(f"   🈹 {key}: {value}")
            elif key == "Jyutping":
                print(f"   🔊 {key}: {value}")
            elif key == "Taishanese (Penyim)":
                print(f"   🎭 {key}: {value}")
            elif key == "Definition":
                print(f"   📚 {key}: {value}")
            else:
                print(f"   ➡️  {key}: {value}")
    
    if i < len(docs_and_scores):
        print(f"   {'─' * 40}")

print(f"\n✅ Found {len(docs_and_scores)} results")
# Out:
# 🔍 Similarity Search Results for 'happy'
# ==================================================
#
# 📍 Result #1
#    Similarity Score: 1.6068
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['笑嘻嘻']
#    🔊 Jyutping: ['xël-hī-hī']
#    🎭 Taishanese (Penyim): ['xiàoxīxī']
#    📚 Definition: grinning; smiling broadly.⁵
#    ────────────────────────────────────────
#
# 📍 Result #2
#    Similarity Score: 1.6068
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['佞幸']
#    🔊 Jyutping: ['nèin-hàng']
#    🎭 Taishanese (Penyim): ['nìngxìng']
#    📚 Definition: flattering courtiers; favorite of king.¹¹
#    ────────────────────────────────────────
#
# 📍 Result #3
#    Similarity Score: 1.6056
#    ────────────────────────────────────────
#    🈶 Traditional: ['賠笑']
#    🈹 Simplified: ['赔笑']
#    🔊 Jyutping: ['põi-xël']
#    🎭 Taishanese (Penyim): ['péixiào']
#    📚 Definition: smile placatingly or apologetically; smile a fawning smile.⁶
#    ────────────────────────────────────────
#
# 📍 Result #4
#    Similarity Score: 1.6035
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['嘻嘻']
#    🔊 Jyutping: ['hī-hī']
#    🎭 Taishanese (Penyim): ['xīxī']
#    📚 Definition: hee hee; happy.¹⁰
#    ────────────────────────────────────────
#
# 📍 Result #5
#    Similarity Score: 1.5989
#    ────────────────────────────────────────
#    🈶 Traditional: 福
#    🈹 Simplified:
#    🔊 Jyutping: fūk
#    🎭 Taishanese (Penyim): fú
#    📚 Definition: good fortune; blessing; happiness.⁵
#    ────────────────────────────────────────
#
# 📍 Result #6
#    Similarity Score: 1.5989
#    ────────────────────────────────────────
#    🈶 Traditional: ['幸虧']
#    🈹 Simplified: ['幸亏']
#    🔊 Jyutping: ['hàng-kï']
#    🎭 Taishanese (Penyim): ['xìngkuī']
#    📚 Definition: fortunately; luckily.¹⁰
#    ────────────────────────────────────────
#
# 📍 Result #7
#    Similarity Score: 1.5976
#    ────────────────────────────────────────
#    🈶 Traditional: 栿
#    🈹 Simplified:
#    🔊 Jyutping: fùk
#    🎭 Taishanese (Penyim): fú
#    📚 Definition: <wr.> roof beam.⁶
#    ────────────────────────────────────────
#
# 📍 Result #8
#    Similarity Score: 1.5957
#    ────────────────────────────────────────
#    🈶 Traditional: 憙
#    🈹 Simplified:
#    🔊 Jyutping: hī
#    🎭 Taishanese (Penyim): xǐ
#    📚 Definition: (=喜 hī xǐ pleasure; joy; pleased with.¹⁴); like, love, enjoy; joyful thing.⁸  to be delighted with; to take delight in.¹⁴ pleased; to approve of.²⁴
#    ────────────────────────────────────────
#
# 📍 Result #9
#    Similarity Score: 1.5940
#    ────────────────────────────────────────
#    🈶 Traditional: ['樂極生悲']
#    🈹 Simplified: ['乐极生悲']
#    🔊 Jyutping: ['lòk-gèik-säng-bï']
#    🎭 Taishanese (Penyim): ['lèjíshēngbēi']
#    📚 Definition: extreme joy turns to sorrow (idiom); Don't celebrate too soon, things could still go wrong!¹⁰
#    ────────────────────────────────────────
#
# 📍 Result #10
#    Similarity Score: 1.5927
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['劭美']
#    🔊 Jyutping: ['sèl-mî']
#    🎭 Taishanese (Penyim): ['shàoměi']
#    📚 Definition: fine, happy.¹⁹
#    ────────────────────────────────────────
#
# 📍 Result #11
#    Similarity Score: 1.5925
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['微笑']
#    🔊 Jyutping: ['mĩ-xël']
#    🎭 Taishanese (Penyim): ['wēixiào']
#    📚 Definition: smile; to smile.¹⁰
#    ────────────────────────────────────────
#
# 📍 Result #12
#    Similarity Score: 1.5923
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['燕嫟之私']
#    🔊 Jyutping: ['yën-nèik-jï-xü']
#    🎭 Taishanese (Penyim): ['yànnìzhīsī']
#    📚 Definition: conjugal happiness.⁵⁴
#    ────────────────────────────────────────
#
# 📍 Result #13
#    Similarity Score: 1.5902
#    ────────────────────────────────────────
#    🈶 Traditional: ['茀祿']
#    🈹 Simplified: ['茀禄']
#    🔊 Jyutping: ['fūt-lùk']
#    🎭 Taishanese (Penyim): ['fúlù']
#    📚 Definition: happiness and emolument.¹⁴
#    ────────────────────────────────────────
#
# 📍 Result #14
#    Similarity Score: 1.5897
#    ────────────────────────────────────────
#    🈶 Traditional: ['七竅生煙']
#    🈹 Simplified: ['七窍生烟']
#    🔊 Jyutping: ['tīt-hël-säng-yën']
#    🎭 Taishanese (Penyim): ['qīqiàoshēngyān']
#    📚 Definition: fumigate with anger.¹¹
#    ────────────────────────────────────────
#
# 📍 Result #15
#    Similarity Score: 1.5895
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['福禄如茨']
#    🔊 Jyutping: ['fūk-lùk-nguĩ-xũ']
#    🎭 Taishanese (Penyim): ['fúlùrúcí']
#    📚 Definition: (in whom) all happiness and dignity are concentrated.¹⁴
#    ────────────────────────────────────────
#
# 📍 Result #16
#    Similarity Score: 1.5874
#    ────────────────────────────────────────
#    🈶 Traditional: ['火燒火燎']
#    🈹 Simplified: ['火烧火燎']
#    🔊 Jyutping: ['fō-sël-fō-lẽl']
#    🎭 Taishanese (Penyim): ['huǒshāohuǒliǎo']
#    📚 Definition: feeling terribly hot; restless with anxiety.⁵
#    ────────────────────────────────────────
#
# 📍 Result #17
#    Similarity Score: 1.5874
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['粲然一笑']
#    🔊 Jyutping: ['tān-ngẽin-yīt-xël']
#    🎭 Taishanese (Penyim): ['cànrányīxiào']
#    📚 Definition: give a beaming smile; grin with delight.⁵
#    ────────────────────────────────────────
#
# 📍 Result #18
#    Similarity Score: 1.5863
#    ────────────────────────────────────────
#    🈶 Traditional: ['眉開眼笑']
#    🈹 Simplified: ['眉开眼笑']
#    🔊 Jyutping: ['mĩ-höi-ngān-xël']
#    🎭 Taishanese (Penyim): ['méikāiyǎnxiào']
#    📚 Definition: be alll smiles; be radiant with smiles; beam with joy.⁶
#    ────────────────────────────────────────
#
# 📍 Result #19
#    Similarity Score: 1.5852
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['福分']
#    🔊 Jyutping: ['fūk-fün']
#    🎭 Taishanese (Penyim): ['fúfen']
#    📚 Definition: happy lot; good fortune.⁵
#    ────────────────────────────────────────
#
# 📍 Result #20
#    Similarity Score: 1.5845
#    ────────────────────────────────────────
#    🈶 Traditional: ['笑逐顏開']
#    🈹 Simplified: ['笑逐颜开']
#    🔊 Jyutping: ['xël-jùk-ngãn-höi']
#    🎭 Taishanese (Penyim): ['xiàozhúyánkāi']
#    📚 Definition: beam with joy/smiles; (one's face) be wreathed in smiles.⁶
#    ────────────────────────────────────────
#
# 📍 Result #21
#    Similarity Score: 1.5845
#    ────────────────────────────────────────
#    🈶 Traditional: ['笑逐顏開']
#    🈹 Simplified: ['笑逐颜开']
#    🔊 Jyutping: ['xël-jùk-ngãn-höi']
#    🎭 Taishanese (Penyim): ['xiàozhúyánkāi']
#    📚 Definition: beam with joy/smiles; (one's face) be wreathed in smiles.⁶
#    ────────────────────────────────────────
#
# 📍 Result #22
#    Similarity Score: 1.5816
#    ────────────────────────────────────────
#    🈶 Traditional: [None, None]
#    🈹 Simplified: ['喜孜孜', '喜滋滋']
#    🔊 Jyutping: [None, 'hī-dü-dü']
#    🎭 Taishanese (Penyim): [None, 'xǐzīzī']
#    📚 Definition: joyful, looking pleased.⁷
#    ────────────────────────────────────────
#
# 📍 Result #23
#    Similarity Score: 1.5816
#    ────────────────────────────────────────
#    🈶 Traditional: [None, None]
#    🈹 Simplified: ['喜孜孜', '喜滋滋']
#    🔊 Jyutping: [None, 'hī-dü-dü']
#    🎭 Taishanese (Penyim): [None, 'xǐzīzī']
#    📚 Definition: joyful, looking pleased.⁷
#    ────────────────────────────────────────
#
# 📍 Result #24
#    Similarity Score: 1.5812
#    ────────────────────────────────────────
#    🈶 Traditional: 咍
#    🈹 Simplified:
#    🔊 Jyutping: fõi
#    🎭 Taishanese (Penyim): hái
#    📚 Definition: ridicule.² laugh.⁸ the sound of laughter; happy; Interjection of astonishment.¹⁴ to laugh and joke.²⁴
#    ────────────────────────────────────────
#
# 📍 Result #25
#    Similarity Score: 1.5797
#    ────────────────────────────────────────
#    🈶 Traditional: ['火雞節快樂']
#    🈹 Simplified: ['火鸡节快乐']
#    🔊 Jyutping: ['fō-gäi-dëik-fäi-lòk']
#    🎭 Taishanese (Penyim): ['huǒjījié']
#    📚 Definition: kuàilè Happy Thanksgiving!
#    ────────────────────────────────────────
#
# 📍 Result #26
#    Similarity Score: 1.5759
#    ────────────────────────────────────────
#    🈶 Traditional: ['幸運']
#    🈹 Simplified: ['幸运']
#    🔊 Jyutping: ['hàng-vùn']
#    🎭 Taishanese (Penyim): ['xìngyùn']
#    📚 Definition: good fortune.¹⁴
#    ────────────────────────────────────────
#
# 📍 Result #27
#    Similarity Score: 1.5755
#    ────────────────────────────────────────
#    🈶 Traditional: ['開心']
#    🈹 Simplified: ['开心']
#    🔊 Jyutping: ['höi-xïm']
#    🎭 Taishanese (Penyim): ['kāixīn']
#    📚 Definition: happy; feel happy.⁵ʼ⁵⁵
#    ────────────────────────────────────────
#
# 📍 Result #28
#    Similarity Score: 1.5652
#    ────────────────────────────────────────
#    🈶 Traditional: ['曷勝欣躍']
#    🈹 Simplified: ['曷胜欣跃']
#    🔊 Jyutping: ['hòt-sëin-hïm-yèk']
#    🎭 Taishanese (Penyim): ['héshèngxīnyuè']
#    📚 Definition: How can I express my delight?¹⁴
#    ────────────────────────────────────────
#
# 📍 Result #29
#    Similarity Score: 1.5650
#    ────────────────────────────────────────
#    🈶 Traditional: ['莞爾']
#    🈹 Simplified: ['莞尔']
#    🔊 Jyutping: ['fōn-ngì']
#    🎭 Taishanese (Penyim): ["wǎn'ěr"]
#    📚 Definition: smiling.¹⁰ <wr.> smilingly.¹¹
#    ────────────────────────────────────────
#
# 📍 Result #30
#    Similarity Score: 1.5649
#    ────────────────────────────────────────
#    🈶 Traditional: [None, None]
#    🈹 Simplified: ['欣幸', '忻幸']
#    🔊 Jyutping: [None, 'hïm-hàng']
#    🎭 Taishanese (Penyim): [None, 'xīnxìng']
#    📚 Definition: be glad and thankful.⁵
#    ────────────────────────────────────────
#
# 📍 Result #31
#    Similarity Score: 1.5648
#    ────────────────────────────────────────
#    🈶 Traditional: 咥
#    🈹 Simplified:
#    🔊 Jyutping: hï
#    🎭 Taishanese (Penyim): xì
#    📚 Definition: to smile; to sneer at; to mock.⁸ loud laugh.¹⁰ʼ³⁵ to roar in laughter.¹¹ a loud laugh.¹⁴ risus, ridicule.³⁶ hee hee!; giggle, laugh; to laugh out loud.⁵⁴
#    ────────────────────────────────────────
#
# 📍 Result #32
#    Similarity Score: 1.5620
#    ────────────────────────────────────────
#    🈶 Traditional: ['曷勝感戴']
#    🈹 Simplified: ['曷胜感戴']
#    🔊 Jyutping: ['hòt-sëin-gām-äi']
#    🎭 Taishanese (Penyim): ['héshènggǎndài']
#    📚 Definition: How can I adequately express my gratitude?¹⁴
#    ────────────────────────────────────────
#
# 📍 Result #33
#    Similarity Score: 1.5592
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['愉快']
#    🔊 Jyutping: ['yĩ-fäi']
#    🎭 Taishanese (Penyim): ['yúkuài']
#    📚 Definition: happy; joyful; cheerful; delighted.⁶
#    ────────────────────────────────────────
#
# 📍 Result #34
#    Similarity Score: 1.5556
#    ────────────────────────────────────────
#    🈶 Traditional: ['幸災樂禍']
#    🈹 Simplified: ['幸灾乐祸']
#    🔊 Jyutping: ['hàng-döi-lòk-vò']
#    🎭 Taishanese (Penyim): ['xìngzāilèhuò']
#    📚 Definition: schadenfreude, to gloat at another's misfortune.⁶ʼ⁰
#    ────────────────────────────────────────
#
# 📍 Result #35
#    Similarity Score: 1.5485
#    ────────────────────────────────────────
#    🈶 Traditional: ['知足常樂']
#    🈹 Simplified: ['知足常乐']
#    🔊 Jyutping: ['jï-dūk-sẽng-lòk']
#    🎭 Taishanese (Penyim): ['zhīzúchánglè']
#    📚 Definition: content-ment brings happiness.⁶ Be content with what you have.⁰
#    ────────────────────────────────────────
#
# 📍 Result #36
#    Similarity Score: 1.5481
#    ────────────────────────────────────────
#    🈶 Traditional: [None, None]
#    🈹 Simplified: ['甜津津', '甜滋滋']
#    🔊 Jyutping: ['hẽm-jün-jün', 'hẽm-dü-dü']
#    🎭 Taishanese (Penyim): ['tiánjīnjīn', 'tiánzīzī']
#    📚 Definition: pleasantly sweet; happy, gratified, quite pleased.⁵⁴
#    ────────────────────────────────────────
#
# 📍 Result #37
#    Similarity Score: 1.5461
#    ────────────────────────────────────────
#    🈶 Traditional: 悇
#    🈹 Simplified:
#    🔊 Jyutping: yĩ
#    🎭 Taishanese (Penyim): yú
#    📚 Definition: happy.² delighted.²⁴
#    ────────────────────────────────────────
#
# 📍 Result #38
#    Similarity Score: 1.5424
#    ────────────────────────────────────────
#    🈶 Traditional: 恞
#    🈹 Simplified:
#    🔊 Jyutping: yĩ
#    🎭 Taishanese (Penyim): yí
#    📚 Definition: happy; joyous.¹⁰ pleased, delighted.²⁴
#    ────────────────────────────────────────
#
# 📍 Result #39
#    Similarity Score: 1.5389
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['笑容']
#    🔊 Jyutping: ['xël-yũng']
#    🎭 Taishanese (Penyim): ['xiàoróng']
#    📚 Definition: smiling expression; smile.⁵
#    ────────────────────────────────────────
#
# 📍 Result #40
#    Similarity Score: 1.5361
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['遐福']
#    🔊 Jyutping: ['hã-fūk']
#    🎭 Taishanese (Penyim): ['xiáfú']
#    📚 Definition: great happiness.³⁹
#    ────────────────────────────────────────
#
# 📍 Result #41
#    Similarity Score: 1.5336
#    ────────────────────────────────────────
#    🈶 Traditional: 忭
#    🈹 Simplified:
#    🔊 Jyutping: bèin
#    🎭 Taishanese (Penyim): biàn
#    📚 Definition: <wr.> glad, happy.⁵ overjoyed; pleased; delighted.⁷
#    ────────────────────────────────────────
#
# 📍 Result #42
#    Similarity Score: 1.5299
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['痛快']
#    🔊 Jyutping: ['hüng-fäi']
#    🎭 Taishanese (Penyim): ['tòngkuai']
#    📚 Definition: happy; joyful; delighted.⁶
#    ────────────────────────────────────────
#
# 📍 Result #43
#    Similarity Score: 1.5275
#    ────────────────────────────────────────
#    🈶 Traditional: 唍
#    🈹 Simplified:
#    🔊 Jyutping: fōn
#    🎭 Taishanese (Penyim): wǎn
#    📚 Definition: smile.² a slight smile.²⁴ (=莞 fōn wǎn to smile.¹⁰).¹⁰¹
#    ────────────────────────────────────────
#
# 📍 Result #44
#    Similarity Score: 1.5271
#    ────────────────────────────────────────
#    🈶 Traditional: ['知足常樂', '知足長樂']
#    🈹 Simplified: ['知足常乐', '知足长乐']
#    🔊 Jyutping: ['jï-dūk-sẽng-lòk', 'jï-dūk-chẽng-lòk']
#    🎭 Taishanese (Penyim): [None, 'zhīzúchánglè']
#    📚 Definition: contentment brings happiness; enough is as good as a feast.⁶ he who is contented is always happy.¹¹
#    ────────────────────────────────────────
#
# 📍 Result #45
#    Similarity Score: 1.5250
#    ────────────────────────────────────────
#    🈶 Traditional: ['慶幸']
#    🈹 Simplified: ['庆幸']
#    🔊 Jyutping: ['hëin-hàng']
#    🎭 Taishanese (Penyim): ['qìngxìng']
#    📚 Definition: to rejoice; to be glad.¹⁰
#    ────────────────────────────────────────
#
# 📍 Result #46
#    Similarity Score: 1.5204
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['福履']
#    🔊 Jyutping: ['fūk-lî']
#    🎭 Taishanese (Penyim): ['fúlǚ']
#    📚 Definition: blessings.¹¹ happiness and success in one's career.⁵⁴
#    ────────────────────────────────────────
#
# 📍 Result #47
#    Similarity Score: 1.5174
#    ────────────────────────────────────────
#    🈶 Traditional: 怫
#    🈹 Simplified:
#    🔊 Jyutping: fūt
#    🎭 Taishanese (Penyim): fú
#    📚 Definition: depressed and discontented.⁵ looking anger; glowering.⁶
#    ────────────────────────────────────────
#
# 📍 Result #48
#    Similarity Score: 1.4978
#    ────────────────────────────────────────
#    🈶 Traditional: ['獰笑']
#    🈹 Simplified: ['狞笑']
#    🔊 Jyutping: ['nẽin-xël']
#    🎭 Taishanese (Penyim): ['níngxiào']
#    📚 Definition: grin hideously; peal of blustering laughter.⁸ sardonic smile; to laugh maliciously.¹⁰ a hideous, hypocritical smile.¹¹
#    ────────────────────────────────────────
#
# 📍 Result #49
#    Similarity Score: 1.4957
#    ────────────────────────────────────────
#    🈶 Traditional: [None]
#    🈹 Simplified: ['幸福']
#    🔊 Jyutping: ['hàng-fūk']
#    🎭 Taishanese (Penyim): ['xìngfú']
#    📚 Definition: happiness, well-being; happy.⁵
#    ────────────────────────────────────────
#
# 📍 Result #50
#    Similarity Score: 1.4743
#    ────────────────────────────────────────
#    🈶 Traditional: 㰻
#    🈹 Simplified:
#    🔊 Jyutping: hï
#    🎭 Taishanese (Penyim): xī
#    📚 Definition: to be happy suddenly.²ʼ⁸ sudden delight.²⁴
#
# ✅ Found 50 results
